# %% [markdown]
# # Analyze international debt statistics

# %%
import sqlite3

# %%
conn = sqlite3.connect('test.db')

# %%
import pandas as pd

df = pd.read_csv('international_debt.csv')
df.to_sql('international_debt', conn, if_exists='replace', index=False)

query = "SELECT * FROM international_debt;"
result = pd.read_sql(query, conn)

result
# Out:
#      country_name country_code  \
# 0     Afghanistan          AFG
# 1     Afghanistan          AFG
# 2     Afghanistan          AFG
# 3     Afghanistan          AFG
# 4     Afghanistan          AFG
# ...           ...          ...
# 2352     Zimbabwe          ZWE
# 2353     Zimbabwe          ZWE
# 2354     Zimbabwe          ZWE
# 2355     Zimbabwe          ZWE
# 2356     Zimbabwe          ZWE
#
#                                          indicator_name  indicator_code  \
# 0     Disbursements on external debt, long-term (DIS...  DT.DIS.DLXF.CD
# 1     Interest payments on external debt, long-term ...  DT.INT.DLXF.CD
# 2                     PPG, bilateral (AMT, current US$)  DT.AMT.BLAT.CD
# 3                     PPG, bilateral (DIS, current US$)  DT.DIS.BLAT.CD
# 4                     PPG, bilateral (INT, current US$)  DT.INT.BLAT.CD
# ...                                                 ...             ...
# 2352         PPG, official creditors (AMT, current US$)  DT.AMT.OFFT.CD
# 2353         PPG, official creditors (DIS, current US$)  DT.DIS.OFFT.CD
# 2354         PPG, official creditors (INT, current US$)  DT.INT.OFFT.CD
# 2355  Principal repayments on external debt, long-te...  DT.AMT.DLXF.CD
# 2356  Principal repayments on external debt, private...  DT.AMT.DPNG.CD
#
#              debt
# 0      72894453.7
# 1      53239440.1
# 2      61739336.9
# 3      49114729.4
# 4      39903620.1
# ...           ...
# 2352   98492119.9
# 2353   44396033.7
# 2354   15761660.0
# 2355  461632253.7
# 2356  363140133.8
#
# [2357 rows x 5 columns]

# %% [markdown]
# # The number of countries with debt

# %%
query = """
SELECT
    Count(DISTINCT(country_name)) AS number_of_countries
FROM international_debt;

"""

result = pd.read_sql(query, conn)

result
# Out:
#    number_of_countries
# 0                  124

# %% [markdown]
# # The total amount of debt owed by all the countries

# %%
pd.options.display.float_format = '{:.0f}'.format

query = """
SELECT
    Sum(debt) AS total_debt
FROM international_debt;

"""

result = pd.read_sql(query, conn)

result
# Out:
#      total_debt
# 0 3079734487676

# %% [markdown]
# So, The total amount of debt owed by all the countries is three billion seventy-nine billion seven hundred thirty-four million four hundred eighty-seven thousand six hundred seventy-six dolars
#
# Wow 🤯

# %% [markdown]
# # Top 10 countries with the highest debt and the amount of its debt

# %%
query = """
SELECT
    country_name, Sum(debt) AS highest_debt
FROM international_debt
Group by country_name
Order by highest_debt desc
Limit 10;

"""

result = pd.read_sql(query, conn)

result
# Out:
#                                    country_name  highest_debt
# 0                                         China  285793494734
# 1                                        Brazil  280623966141
# 2                                    South Asia  247608723991
# 3  Least developed countries: UN classification  212880992792
# 4                            Russian Federation  191289057259
# 5                                      IDA only  179048127207
# 6                                        Turkey  151125758035
# 7                                         India  133627060958
# 8                                        Mexico  124596786217
# 9                                     Indonesia  113435696694

# %% [markdown]
# # Top 10 countries with the lowest debt and the amount of its debt

# %%
query = """
SELECT
    country_name, Sum(debt) AS highest_debt
FROM international_debt
Group by country_name
Order by highest_debt asc
Limit 10;

"""

result = pd.read_sql(query, conn)

result
# Out:
#             country_name  highest_debt
# 0  Sao Tome and Principe      44798032
# 1                  Tonga      55209305
# 2                Comoros      57568483
# 3            Timor-Leste      71000959
# 4           Turkmenistan      95135629
# 5        Solomon Islands     105104467
# 6                  Samoa     112946426
# 7                Somalia     119614075
# 8                Eritrea     132493809
# 9               Dominica     138044300

# %% [markdown]
# # The average amount of debt owed by countries across different debt indicators

# %%
query = """
SELECT
    Distinct indicator_code as debt_indicator_code
FROM international_debt

"""

result = pd.read_sql(query, conn)

result
# Out:
#    debt_indicator_code
# 0       DT.DIS.DLXF.CD
# 1       DT.INT.DLXF.CD
# 2       DT.AMT.BLAT.CD
# 3       DT.DIS.BLAT.CD
# 4       DT.INT.BLAT.CD
# 5       DT.AMT.MLAT.CD
# 6       DT.DIS.MLAT.CD
# 7       DT.INT.MLAT.CD
# 8       DT.AMT.OFFT.CD
# 9       DT.DIS.OFFT.CD
# 10      DT.INT.OFFT.CD
# 11      DT.AMT.DLXF.CD
# 12      DT.INT.DPNG.CD
# 13      DT.AMT.PBND.CD
# 14      DT.INT.PBND.CD
# 15      DT.AMT.PCBK.CD
# 16      DT.DIS.PCBK.CD
# 17      DT.INT.PCBK.CD
# 18      DT.AMT.PROP.CD
# 19      DT.DIS.PROP.CD
# 20      DT.INT.PROP.CD
# 21      DT.AMT.PRVT.CD
# 22      DT.DIS.PRVT.CD
# 23      DT.INT.PRVT.CD
# 24      DT.AMT.DPNG.CD

# %%
query = """
SELECT
    indicator_code, indicator_name, avg(debt) as average_dept
FROM international_debt
Group by indicator_code, indicator_name
Order by average_dept desc

"""

result = pd.read_sql(query, conn)

result
# Out:
#     indicator_code                                     indicator_name  \
# 0   DT.AMT.DLXF.CD  Principal repayments on external debt, long-te...
# 1   DT.AMT.DPNG.CD  Principal repayments on external debt, private...
# 2   DT.DIS.DLXF.CD  Disbursements on external debt, long-term (DIS...
# 3   DT.DIS.OFFT.CD         PPG, official creditors (DIS, current US$)
# 4   DT.AMT.PRVT.CD          PPG, private creditors (AMT, current US$)
# 5   DT.INT.DLXF.CD  Interest payments on external debt, long-term ...
# 6   DT.DIS.BLAT.CD                  PPG, bilateral (DIS, current US$)
# 7   DT.INT.DPNG.CD  Interest payments on external debt, private no...
# 8   DT.AMT.OFFT.CD         PPG, official creditors (AMT, current US$)
# 9   DT.AMT.PBND.CD                      PPG, bonds (AMT, current US$)
# 10  DT.DIS.MLAT.CD               PPG, multilateral (DIS, current US$)
# 11  DT.INT.PBND.CD                      PPG, bonds (INT, current US$)
# 12  DT.AMT.PROP.CD    PPG, other private creditors (AMT, current US$)
# 13  DT.AMT.PCBK.CD           PPG, commercial banks (AMT, current US$)
# 14  DT.INT.PRVT.CD          PPG, private creditors (INT, current US$)
# 15  DT.AMT.BLAT.CD                  PPG, bilateral (AMT, current US$)
# 16  DT.AMT.MLAT.CD               PPG, multilateral (AMT, current US$)
# 17  DT.DIS.PRVT.CD          PPG, private creditors (DIS, current US$)
# 18  DT.INT.OFFT.CD         PPG, official creditors (INT, current US$)
# 19  DT.DIS.PCBK.CD           PPG, commercial banks (DIS, current US$)
# 20  DT.INT.BLAT.CD                  PPG, bilateral (INT, current US$)
# 21  DT.INT.PCBK.CD           PPG, commercial banks (INT, current US$)
# 22  DT.INT.MLAT.CD               PPG, multilateral (INT, current US$)
# 23  DT.DIS.PROP.CD    PPG, other private creditors (DIS, current US$)
# 24  DT.INT.PROP.CD    PPG, other private creditors (INT, current US$)
#
#     average_dept
# 0     5904868401
# 1     5161194334
# 2     2152041217
# 3     1958983453
# 4     1803694102
# 5     1644024068
# 6     1223139290
# 7     1220410844
# 8     1191187963
# 9     1082623948
# 10     839843679
# 11     804733377
# 12     746888800
# 13     734868743
# 14     719740180
# 15     712619635
# 16     490062193
# 17     311323265
# 18     297677339
# 19     293305196
# 20     164093286
# 21     156647613
# 22     136230719
# 23      81135161
# 24      34250651

# %% [markdown]
# # The most common debt indicator

# %%
query = """
SELECT
    indicator_code, indicator_name, count(indicator_code) as count_indicator
FROM international_debt
Group by indicator_code, indicator_name
Order by count_indicator desc

"""

result = pd.read_sql(query, conn)

result
# Out:
#     indicator_code                                     indicator_name  \
# 0   DT.AMT.DLXF.CD  Principal repayments on external debt, long-te...
# 1   DT.AMT.MLAT.CD               PPG, multilateral (AMT, current US$)
# 2   DT.AMT.OFFT.CD         PPG, official creditors (AMT, current US$)
# 3   DT.INT.DLXF.CD  Interest payments on external debt, long-term ...
# 4   DT.INT.MLAT.CD               PPG, multilateral (INT, current US$)
# 5   DT.INT.OFFT.CD         PPG, official creditors (INT, current US$)
# 6   DT.DIS.DLXF.CD  Disbursements on external debt, long-term (DIS...
# 7   DT.AMT.BLAT.CD                  PPG, bilateral (AMT, current US$)
# 8   DT.DIS.OFFT.CD         PPG, official creditors (DIS, current US$)
# 9   DT.INT.BLAT.CD                  PPG, bilateral (INT, current US$)
# 10  DT.DIS.MLAT.CD               PPG, multilateral (DIS, current US$)
# 11  DT.DIS.BLAT.CD                  PPG, bilateral (DIS, current US$)
# 12  DT.AMT.PRVT.CD          PPG, private creditors (AMT, current US$)
# 13  DT.INT.PRVT.CD          PPG, private creditors (INT, current US$)
# 14  DT.AMT.PCBK.CD           PPG, commercial banks (AMT, current US$)
# 15  DT.INT.PCBK.CD           PPG, commercial banks (INT, current US$)
# 16  DT.AMT.DPNG.CD  Principal repayments on external debt, private...
# 17  DT.INT.DPNG.CD  Interest payments on external debt, private no...
# 18  DT.AMT.PBND.CD                      PPG, bonds (AMT, current US$)
# 19  DT.INT.PBND.CD                      PPG, bonds (INT, current US$)
# 20  DT.AMT.PROP.CD    PPG, other private creditors (AMT, current US$)
# 21  DT.INT.PROP.CD    PPG, other private creditors (INT, current US$)
# 22  DT.DIS.PRVT.CD          PPG, private creditors (DIS, current US$)
# 23  DT.DIS.PCBK.CD           PPG, commercial banks (DIS, current US$)
# 24  DT.DIS.PROP.CD    PPG, other private creditors (DIS, current US$)
#
#     count_indicator
# 0               124
# 1               124
# 2               124
# 3               124
# 4               124
# 5               124
# 6               123
# 7               122
# 8               122
# 9               122
# 10              120
# 11              113
# 12               98
# 13               98
# 14               84
# 15               84
# 16               79
# 17               79
# 18               69
# 19               69
# 20               54
# 21               54
# 22               53
# 23               51
# 24               19

# %% [markdown]
# # International debt for Ukraine

# %%
query = """
SELECT
    country_name, indicator_code, indicator_name, debt
FROM international_debt
Where country_name = "Ukraine"
Group by indicator_name
Order by debt desc;

"""

result = pd.read_sql(query, conn)

result
# Out:
#    country_name  indicator_code  \
# 0       Ukraine  DT.AMT.DLXF.CD
# 1       Ukraine  DT.AMT.DPNG.CD
# 2       Ukraine  DT.INT.DLXF.CD
# 3       Ukraine  DT.AMT.PRVT.CD
# 4       Ukraine  DT.AMT.PBND.CD
# 5       Ukraine  DT.INT.DPNG.CD
# 6       Ukraine  DT.INT.PRVT.CD
# 7       Ukraine  DT.INT.PBND.CD
# 8       Ukraine  DT.AMT.OFFT.CD
# 9       Ukraine  DT.AMT.MLAT.CD
# 10      Ukraine  DT.DIS.OFFT.CD
# 11      Ukraine  DT.DIS.MLAT.CD
# 12      Ukraine  DT.DIS.DLXF.CD
# 13      Ukraine  DT.INT.OFFT.CD
# 14      Ukraine  DT.AMT.PROP.CD
# 15      Ukraine  DT.INT.MLAT.CD
# 16      Ukraine  DT.AMT.BLAT.CD
# 17      Ukraine  DT.INT.BLAT.CD
# 18      Ukraine  DT.INT.PROP.CD
#
#                                        indicator_name       debt
# 0   Principal repayments on external debt, long-te... 8148995626
# 1   Principal repayments on external debt, private... 4844593102
# 2   Interest payments on external debt, long-term ... 3001506404
# 3           PPG, private creditors (AMT, current US$) 2135988474
# 4                       PPG, bonds (AMT, current US$) 1977107000
# 5   Interest payments on external debt, private no... 1647660000
# 6           PPG, private creditors (INT, current US$) 1180164511
# 7                       PPG, bonds (INT, current US$) 1176828000
# 8          PPG, official creditors (AMT, current US$) 1168414050
# 9                PPG, multilateral (AMT, current US$) 1072472830
# 10         PPG, official creditors (DIS, current US$)  510350371
# 11               PPG, multilateral (DIS, current US$)  510350371
# 12  Disbursements on external debt, long-term (DIS...  510350371
# 13         PPG, official creditors (INT, current US$)  173681893
# 14    PPG, other private creditors (AMT, current US$)  158881474
# 15               PPG, multilateral (INT, current US$)  153872077
# 16                  PPG, bilateral (AMT, current US$)   95941219
# 17                  PPG, bilateral (INT, current US$)   19809817
# 18    PPG, other private creditors (INT, current US$)    3336511

# %%
query = """
SELECT
    country_name, sum(debt)
FROM international_debt
Where country_name = "Ukraine";

"""

result = pd.read_sql(query, conn)

result
# Out:
#   country_name   sum(debt)
# 0      Ukraine 28490304100

# %% [markdown]
# # Top 10 countries with the lowest debt indicators

# %%
query = """
SELECT country_name, COUNT(indicator_code) AS num_indicators
FROM international_debt
GROUP BY country_name
Order by num_indicators asc
Limit 10

"""

result = pd.read_sql(query, conn)

result
# Out:
#     country_name  num_indicators
# 0    Timor-Leste              10
# 1   Turkmenistan              10
# 2  Guinea-Bissau              11
# 3        Somalia              11
# 4    Afghanistan              12
# 5   Burkina Faso              12
# 6        Burundi              12
# 7        Comoros              12
# 8         Malawi              12
# 9     Mauritania              12
